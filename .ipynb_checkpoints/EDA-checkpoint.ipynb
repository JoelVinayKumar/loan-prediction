# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# # Reading Data from CSV files

# %%
dataset = pd.read_csv("LoanData.csv")

# %%
dataset.head(1)
# Out:
#                                 Loan ID                           Customer ID  \
# 0  14dd8831-6af5-400b-83ec-68e61888a048  981165ec-3274-42f5-a3b4-d104041a9ca9
#
#   Loan Status  Current Loan Amount        Term  Credit Score  Annual Income  \
# 0  Fully Paid             445412.0  Short Term         709.0      1167493.0
#
#   Years in current job Home Ownership            Purpose  Monthly Debt  \
# 0              8 years  Home Mortgage  Home Improvements       5214.74
#
#    Years of Credit History  Months since last delinquent  \
# 0                     17.2                           NaN
#
#    Number of Open Accounts  Number of Credit Problems  Current Credit Balance  \
# 0                      6.0                        1.0                228190.0
#
#    Maximum Open Credit  Bankruptcies  Tax Liens
# 0             416746.0           1.0        0.0

# %% [markdown]
# # Dropping duplicates from both train and test data

# %%
dataset = dataset.drop_duplicates(keep='first')

# %% [markdown]
# # Looking through the data

# %%
dataset.shape
# Out:
# (89786, 19)

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 89786 entries, 0 to 100000
# Data columns (total 19 columns):
# Loan ID                         89785 non-null object
# Customer ID                     89785 non-null object
# Loan Status                     89785 non-null object
# Current Loan Amount             89785 non-null float64
# Term                            89785 non-null object
# Credit Score                    70631 non-null float64
# Annual Income                   70631 non-null float64
# Years in current job            85983 non-null object
# Home Ownership                  89785 non-null object
# Purpose                         89785 non-null object
# Monthly Debt                    89785 non-null float64
# Years of Credit History         89785 non-null float64
# Months since last delinquent    41448 non-null float64
# Number of Open Accounts         89785 non-null float64
# Number of Credit Problems       89785 non-null float64
# Current Credit Balance          89785 non-null float64
# Maximum Open Credit             89783 non-null float64
# Bankruptcies                    89595 non-null float64
# Tax Liens                       89776 non-null float64
# dtypes: float64(12), object(7)
# memory usage: 13.7+ MB

# %%
dataset.describe()
# Out:
#        Current Loan Amount  Credit Score  Annual Income   Monthly Debt  \
# count         8.978500e+04  70631.000000   7.063100e+04   89785.000000
# mean          1.306089e+07   1130.830598   1.375894e+06   18396.906410
# std           3.329556e+07   1571.037395   1.104852e+06   12145.282372
# min           1.080200e+04    585.000000   7.662700e+04       0.000000
# 25%           1.802680e+05    708.000000   8.479320e+05   10157.400000
# 50%           3.138740e+05    729.000000   1.168975e+06   16140.310000
# 75%           5.323780e+05    742.000000   1.648915e+06   23918.910000
# max           1.000000e+08   7510.000000   1.655574e+08  435843.280000
#
#        Years of Credit History  Months since last delinquent  \
# count             89785.000000                  41448.000000
# mean                 18.248642                     34.975873
# std                   7.034607                     22.008585
# min                   3.600000                      0.000000
# 25%                  13.500000                     16.000000
# 50%                  17.000000                     32.000000
# 75%                  21.700000                     51.000000
# max                  70.500000                    176.000000
#
#        Number of Open Accounts  Number of Credit Problems  \
# count             89785.000000               89785.000000
# mean                 11.123250                   0.164983
# std                   4.998884                   0.478010
# min                   0.000000                   0.000000
# 25%                   8.000000                   0.000000
# 50%                  10.000000                   0.000000
# 75%                  14.000000                   0.000000
# max                  76.000000                  15.000000
#
#        Current Credit Balance  Maximum Open Credit  Bankruptcies     Tax Liens
# count            8.978500e+04         8.978300e+04  89595.000000  89776.000000
# mean             2.940351e+05         7.756565e+05      0.115531      0.028605
# std              3.722277e+05         8.803517e+06      0.347919      0.255108
# min              0.000000e+00         0.000000e+00      0.000000      0.000000
# 25%              1.129360e+05         2.770680e+05      0.000000      0.000000
# 50%              2.097220e+05         4.726920e+05      0.000000      0.000000
# 75%              3.675170e+05         7.914500e+05      0.000000      0.000000
# max              3.287897e+07         1.539738e+09      7.000000     15.000000

# %%
dataset.corr()
# Out:
#                               Current Loan Amount  Credit Score  \
# Current Loan Amount                      1.000000     -0.113523
# Credit Score                            -0.113523      1.000000
# Annual Income                            0.014544     -0.017255
# Monthly Debt                            -0.005019      0.000422
# Years of Credit History                  0.017628     -0.012809
# Months since last delinquent             0.010817     -0.005229
# Number of Open Accounts                  0.001828      0.007264
# Number of Credit Problems               -0.000267     -0.001034
# Current Credit Balance                   0.004524      0.000474
# Maximum Open Credit                     -0.001957     -0.003435
# Bankruptcies                             0.001858     -0.005474
# Tax Liens                               -0.001144      0.006413
#
#                               Annual Income  Monthly Debt  \
# Current Loan Amount                0.014544     -0.005019
# Credit Score                      -0.017255      0.000422
# Annual Income                      1.000000      0.472246
# Monthly Debt                       0.472246      1.000000
# Years of Credit History            0.156126      0.196123
# Months since last delinquent      -0.075784     -0.055824
# Number of Open Accounts            0.142222      0.409940
# Number of Credit Problems         -0.016749     -0.054212
# Current Credit Balance             0.300975      0.477464
# Maximum Open Credit                0.046992      0.036638
# Bankruptcies                      -0.047065     -0.079015
# Tax Liens                          0.039407      0.021354
#
#                               Years of Credit History  \
# Current Loan Amount                          0.017628
# Credit Score                                -0.012809
# Annual Income                                0.156126
# Monthly Debt                                 0.196123
# Years of Credit History                      1.000000
# Months since last delinquent                -0.043777
# Number of Open Accounts                      0.130672
# Number of Credit Problems                    0.062091
# Current Credit Balance                       0.209311
# Maximum Open Credit                          0.030779
# Bankruptcies                                 0.066425
# Tax Liens                                    0.018654
#
#                               Months since last delinquent  \
# Current Loan Amount                               0.010817
# Credit Score                                     -0.005229
# Annual Income                                    -0.075784
# Monthly Debt                                     -0.055824
# Years of Credit History                          -0.043777
# Months since last delinquent                      1.000000
# Number of Open Accounts                          -0.033023
# Number of Credit Problems                         0.101517
# Current Credit Balance                           -0.029150
# Maximum Open Credit                              -0.008720
# Bankruptcies                                      0.121234
# Tax Liens                                         0.011041
#
#                               Number of Open Accounts  \
# Current Loan Amount                          0.001828
# Credit Score                                 0.007264
# Annual Income                                0.142222
# Monthly Debt                                 0.409940
# Years of Credit History                      0.130672
# Months since last delinquent                -0.033023
# Number of Open Accounts                      1.000000
# Number of Credit Problems                   -0.015035
# Current Credit Balance                       0.228274
# Maximum Open Credit                          0.030043
# Bankruptcies                                -0.025306
# Tax Liens                                    0.006540
#
#                               Number of Credit Problems  \
# Current Loan Amount                           -0.000267
# Credit Score                                  -0.001034
# Annual Income                                 -0.016749
# Monthly Debt                                  -0.054212
# Years of Credit History                        0.062091
# Months since last delinquent                   0.101517
# Number of Open Accounts                       -0.015035
# Number of Credit Problems                      1.000000
# Current Credit Balance                        -0.111790
# Maximum Open Credit                           -0.012065
# Bankruptcies                                   0.753178
# Tax Liens                                      0.581343
#
#                               Current Credit Balance  Maximum Open Credit  \
# Current Loan Amount                         0.004524            -0.001957
# Credit Score                                0.000474            -0.003435
# Annual Income                               0.300975             0.046992
# Monthly Debt                                0.477464             0.036638
# Years of Credit History                     0.209311             0.030779
# Months since last delinquent               -0.029150            -0.008720
# Number of Open Accounts                     0.228274             0.030043
# Number of Credit Problems                  -0.111790            -0.012065
# Current Credit Balance                      1.000000             0.131892
# Maximum Open Credit                         0.131892             1.000000
# Bankruptcies                               -0.122237            -0.014270
# Tax Liens                                  -0.014913            -0.001652
#
#                               Bankruptcies  Tax Liens
# Current Loan Amount               0.001858  -0.001144
# Credit Score                     -0.005474   0.006413
# Annual Income                    -0.047065   0.039407
# Monthly Debt                     -0.079015   0.021354
# Years of Credit History           0.066425   0.018654
# Months since last delinquent      0.121234   0.011041
# Number of Open Accounts          -0.025306   0.006540
# Number of Credit Problems         0.753178   0.581343
# Current Credit Balance           -0.122237  -0.014913
# Maximum Open Credit              -0.014270  -0.001652
# Bankruptcies                      1.000000   0.046271
# Tax Liens                         0.046271   1.000000

# %%
plt.matshow(dataset.corr())

# %% [markdown]
# # Removing unnecessary values from the data (IDs)

# %%
dataset.drop(['Loan ID','Customer ID'],axis=1,inplace = True)

# %% [markdown]
# # Checking for null values

# %% [markdown]
# sns.heatmap(data_train.isnull())

# %%
dataset.isnull().sum()
# Out:
# Loan Status                         1
# Current Loan Amount                 1
# Term                                1
# Credit Score                    19155
# Annual Income                   19155
# Years in current job             3803
# Home Ownership                      1
# Purpose                             1
# Monthly Debt                        1
# Years of Credit History             1
# Months since last delinquent    48338
# Number of Open Accounts             1
# Number of Credit Problems           1
# Current Credit Balance              1
# Maximum Open Credit                 3
# Bankruptcies                      191
# Tax Liens                          10
# dtype: int64

# %%
dataset.isnull().sum()
# Out:
# Loan Status                         1
# Current Loan Amount                 1
# Term                                1
# Credit Score                    19155
# Annual Income                   19155
# Years in current job             3803
# Home Ownership                      1
# Purpose                             1
# Monthly Debt                        1
# Years of Credit History             1
# Months since last delinquent    48338
# Number of Open Accounts             1
# Number of Credit Problems           1
# Current Credit Balance              1
# Maximum Open Credit                 3
# Bankruptcies                      191
# Tax Liens                          10
# dtype: int64

# %% [markdown]
# # Handling Null Values

# %% [markdown]
# Loan Status:
#
# As we need to train our model to predict Loan status we directly drop the null values of this column of training data

# %%
dataset.dropna(subset=['Loan Status'],axis=0,inplace = True)

# %% [markdown]
# Current Loan Amount:
#
# Based on the 'Current Loan Amount' we can decide whether the customer is able to re-pay the loan, so we are dropping the single record which has null value

# %%
dataset.dropna(subset=['Current Loan Amount'],axis=0,inplace = True)

# %% [markdown]
# Annual Income:
#
# From the co-relation matrix we could find that Monthly debit has more co-relation with Annual Income.
# We determine a factor which could get us the missing values of annual income i.e by taking the mean of
# the ratio of 'Annual Income' to 'Monthly debt'
#
# factor = mean( Annual Income / Monthly debt)

# %%
plt.plot(dataset['Monthly Debt'],dataset['Annual Income'],'*')

# %% [markdown]
# As there are outliers in the data we cannot observe the pattern so we plot the graph for sample of 100 data points to observe the relation between the monthly debt and annual income

# %%
sample_data = dataset.head(100)

# %%
plt.plot(sample_data['Annual Income'],sample_data['Monthly Debt'],'*')
plt.title('Annual income Vs Monthly Debt')
plt.xlabel("Annual Income")
plt.ylabel("Monthly Debt")
plt.show()

# %% [markdown]
# From the above graph we could say that the monthly debt is directly proportional to Annual Income

# %%
dataset['debt_to_salary_ratio'] = dataset['Annual Income']/dataset['Monthly Debt']

# %%
dataset['debt_to_salary_ratio'].mean()
# Out:
# inf

# %% [markdown]
# There might be some customers with zero monthly debt which has resulted in the mean of ratio being infinite

# %%
dataset.columns.get_loc("debt_to_salary_ratio")
# Out:
# 17

# %%
dataset.columns.get_loc("debt_to_salary_ratio")
# Out:
# 17

# %%
is_inf = dataset.iloc[:, 17] == np.inf
factor = dataset.ix[~is_inf, 17].mean()
# Out:
# /home/ajaykrishna/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated

# %%
print("factor: {}".format(factor))
# Out:
# factor: 120.89456830602086

# %%
dataset['Annual Income'].fillna(dataset['Monthly Debt']*factor, inplace=True)

# %%
# dataset.isnull().sum()

# %% [markdown]
# Credit Score:
#
# This determines the goodwill of the customer based on past credit history. Usually the Credit score lies between 300 to 850. Based on 76295 records we refill the outlier records and null values of the column.
#
# Excellent/very good credit score: 700 to 850
# Good credit score: 680 to 699
# Average/OK credit score: 620 to 679
# Low credit score: 580 to 619
# Poor credit score: 500 to 579
# Bad credit score: 300 to 499

# %%
score = [300, 499, 579, 619, 679, 699, 850,10000]
# gags = [1,2,3,4,5,6]
tags = ['Bad','Poor','Low','Average','Good','Excellent','Outliers']
dataset['binned'] = pd.cut(dataset['Credit Score'], bins=score, labels=tags)
dataset.head(5)
# Out:
#   Loan Status  Current Loan Amount        Term  Credit Score  Annual Income  \
# 0  Fully Paid             445412.0  Short Term         709.0   1.167493e+06
# 1  Fully Paid             262328.0  Short Term           NaN   4.025303e+06
# 2  Fully Paid           99999999.0  Short Term         741.0   2.231892e+06
# 3  Fully Paid             347666.0   Long Term         721.0   8.069490e+05
# 4  Fully Paid             176220.0  Short Term           NaN   2.495228e+06
#
#   Years in current job Home Ownership             Purpose  Monthly Debt  \
# 0              8 years  Home Mortgage   Home Improvements       5214.74
# 1            10+ years  Home Mortgage  Debt Consolidation      33295.98
# 2              8 years       Own Home  Debt Consolidation      29200.53
# 3              3 years       Own Home  Debt Consolidation       8741.90
# 4              5 years           Rent  Debt Consolidation      20639.70
#
#    Years of Credit History  Months since last delinquent  \
# 0                     17.2                           NaN
# 1                     21.1                           8.0
# 2                     14.9                          29.0
# 3                     12.0                           NaN
# 4                      6.1                           NaN
#
#    Number of Open Accounts  Number of Credit Problems  Current Credit Balance  \
# 0                      6.0                        1.0                228190.0
# 1                     35.0                        0.0                229976.0
# 2                     18.0                        1.0                297996.0
# 3                      9.0                        0.0                256329.0
# 4                     15.0                        0.0                253460.0
#
#    Maximum Open Credit  Bankruptcies  Tax Liens  debt_to_salary_ratio  \
# 0             416746.0           1.0        0.0            223.883262
# 1             850784.0           0.0        0.0                   NaN
# 2             750090.0           0.0        0.0             76.433270
# 3             386958.0           0.0        0.0             92.308194
# 4             427174.0           0.0        0.0                   NaN
#
#       binned
# 0  Excellent
# 1        NaN
# 2  Excellent
# 3  Excellent
# 4        NaN

# %%
dataset.replace(np.inf, 0,inplace =True)

# %%
dataset.groupby('binned')['Credit Score','Current Loan Amount','debt_to_salary_ratio','Maximum Open Credit','Current Credit Balance','Years of Credit History'].mean()
# Out:
#            Credit Score  Current Loan Amount  debt_to_salary_ratio  \
# binned
# Average      659.584837         1.184163e+07            119.457728
# Excellent    730.156273         1.900333e+07            123.079627
# Good         690.715373         1.211760e+07            117.730517
# Low          606.243292         1.044235e+07             89.573998
# Outliers    7108.989233         3.290381e+05            104.111689
#
#            Maximum Open Credit  Current Credit Balance  \
# binned
# Average          592829.469466           315648.684421
# Excellent        794197.610068           290529.393777
# Good             614371.200621           301319.061646
# Low              635501.130590           349245.627907
# Outliers         643030.007473           295616.712371
#
#            Years of Credit History
# binned
# Average                  17.504441
# Excellent                18.443586
# Good                     17.606351
# Low                      17.483721
# Outliers                 17.845968

# %%
dataset.groupby('binned')['Credit Score','Current Loan Amount','debt_to_salary_ratio','Maximum Open Credit','Current Credit Balance','Years of Credit History'].median()
# Out:
#            Credit Score  Current Loan Amount  debt_to_salary_ratio  \
# binned
# Average           663.0             427581.0             65.217629
# Excellent         733.0             313588.0             73.170909
# Good              692.0             366476.0             66.297938
# Low               608.0             497684.0             64.516341
# Outliers         7190.0             292248.0             65.216966
#
#            Maximum Open Credit  Current Credit Balance  \
# binned
# Average               438647.0                228114.0
# Excellent             484330.0                206739.0
# Good                  430661.0                216543.0
# Low                   447986.0                235163.0
# Outliers              447997.0                217835.0
#
#            Years of Credit History
# binned
# Average                       16.4
# Excellent                     17.1
# Good                          16.5
# Low                           16.4
# Outliers                      16.5

# %%
plt.plot(dataset['Bankruptcies'],dataset['Credit Score'],'*')

# %%
plt.plot(dataset['Tax Liens'],dataset['Credit Score'],'*')

# %%
dataset.drop(dataset[dataset['Credit Score'] > 850].index,inplace=True)

# %%
plt.plot(dataset['Bankruptcies'],dataset['Credit Score'],'*')

# %%
plt.plot(dataset['Tax Liens'],dataset['Credit Score'],'*')

# %%
dataset.corr()
# Out:
#                               Current Loan Amount  Credit Score  \
# Current Loan Amount                      1.000000      0.108425
# Credit Score                             0.108425      1.000000
# Annual Income                           -0.054609      0.004603
# Monthly Debt                            -0.004995     -0.087981
# Years of Credit History                  0.016910      0.083330
# Months since last delinquent             0.010663      0.043853
# Number of Open Accounts                  0.002554     -0.028212
# Number of Credit Problems               -0.000205     -0.052349
# Current Credit Balance                   0.004829     -0.013605
# Maximum Open Credit                     -0.002285      0.017533
# Bankruptcies                             0.001597     -0.038268
# Tax Liens                               -0.000566     -0.022643
# debt_to_salary_ratio                     0.000212      0.010637
#
#                               Annual Income  Monthly Debt  \
# Current Loan Amount               -0.054609     -0.004995
# Credit Score                       0.004603     -0.087981
# Annual Income                      1.000000      0.652813
# Monthly Debt                       0.652813      1.000000
# Years of Credit History            0.178034      0.197046
# Months since last delinquent      -0.060883     -0.055093
# Number of Open Accounts            0.226533      0.409197
# Number of Credit Problems         -0.033684     -0.056058
# Current Credit Balance             0.379211      0.485314
# Maximum Open Credit                0.038375      0.034278
# Bankruptcies                      -0.062236     -0.080252
# Tax Liens                          0.033048      0.021150
# debt_to_salary_ratio               0.045127     -0.078712
#
#                               Years of Credit History  \
# Current Loan Amount                          0.016910
# Credit Score                                 0.083330
# Annual Income                                0.178034
# Monthly Debt                                 0.197046
# Years of Credit History                      1.000000
# Months since last delinquent                -0.044231
# Number of Open Accounts                      0.131520
# Number of Credit Problems                    0.061758
# Current Credit Balance                       0.216465
# Maximum Open Credit                          0.030251
# Bankruptcies                                 0.066541
# Tax Liens                                    0.017769
# debt_to_salary_ratio                        -0.006888
#
#                               Months since last delinquent  \
# Current Loan Amount                               0.010663
# Credit Score                                      0.043853
# Annual Income                                    -0.060883
# Monthly Debt                                     -0.055093
# Years of Credit History                          -0.044231
# Months since last delinquent                      1.000000
# Number of Open Accounts                          -0.032888
# Number of Credit Problems                         0.103833
# Current Credit Balance                           -0.030124
# Maximum Open Credit                              -0.008794
# Bankruptcies                                      0.123183
# Tax Liens                                         0.012493
# debt_to_salary_ratio                             -0.010043
#
#                               Number of Open Accounts  \
# Current Loan Amount                          0.002554
# Credit Score                                -0.028212
# Annual Income                                0.226533
# Monthly Debt                                 0.409197
# Years of Credit History                      0.131520
# Months since last delinquent                -0.032888
# Number of Open Accounts                      1.000000
# Number of Credit Problems                   -0.016673
# Current Credit Balance                       0.234503
# Maximum Open Credit                          0.029282
# Bankruptcies                                -0.026818
# Tax Liens                                    0.006147
# debt_to_salary_ratio                        -0.054214
#
#                               Number of Credit Problems  \
# Current Loan Amount                           -0.000205
# Credit Score                                  -0.052349
# Annual Income                                 -0.033684
# Monthly Debt                                  -0.056058
# Years of Credit History                        0.061758
# Months since last delinquent                   0.103833
# Number of Open Accounts                       -0.016673
# Number of Credit Problems                      1.000000
# Current Credit Balance                        -0.117765
# Maximum Open Credit                           -0.012111
# Bankruptcies                                   0.754720
# Tax Liens                                      0.576777
# debt_to_salary_ratio                           0.002415
#
#                               Current Credit Balance  Maximum Open Credit  \
# Current Loan Amount                         0.004829            -0.002285
# Credit Score                               -0.013605             0.017533
# Annual Income                               0.379211             0.038375
# Monthly Debt                                0.485314             0.034278
# Years of Credit History                     0.216465             0.030251
# Months since last delinquent               -0.030124            -0.008794
# Number of Open Accounts                     0.234503             0.029282
# Number of Credit Problems                  -0.117765            -0.012111
# Current Credit Balance                      1.000000             0.125720
# Maximum Open Credit                         0.125720             1.000000
# Bankruptcies                               -0.127876            -0.014213
# Tax Liens                                  -0.016372            -0.001814
# debt_to_salary_ratio                       -0.033110            -0.001326
#
#                               Bankruptcies  Tax Liens  debt_to_salary_ratio
# Current Loan Amount               0.001597  -0.000566              0.000212
# Credit Score                     -0.038268  -0.022643              0.010637
# Annual Income                    -0.062236   0.033048              0.045127
# Monthly Debt                     -0.080252   0.021150             -0.078712
# Years of Credit History           0.066541   0.017769             -0.006888
# Months since last delinquent      0.123183   0.012493             -0.010043
# Number of Open Accounts          -0.026818   0.006147             -0.054214
# Number of Credit Problems         0.754720   0.576777              0.002415
# Current Credit Balance           -0.127876  -0.016372             -0.033110
# Maximum Open Credit              -0.014213  -0.001814             -0.001326
# Bankruptcies                      1.000000   0.044755             -0.001479
# Tax Liens                         0.044755   1.000000             -0.000414
# debt_to_salary_ratio             -0.001479  -0.000414              1.000000

# %%
dataset.isnull().sum()
# Out:
# Loan Status                         0
# Current Loan Amount                 0
# Term                                0
# Credit Score                    19154
# Annual Income                       0
# Years in current job             3556
# Home Ownership                      0
# Purpose                             0
# Monthly Debt                        0
# Years of Credit History             0
# Months since last delinquent    45866
# Number of Open Accounts             0
# Number of Credit Problems           0
# Current Credit Balance              0
# Maximum Open Credit                 1
# Bankruptcies                      180
# Tax Liens                           9
# debt_to_salary_ratio            19154
# binned                          19154
# dtype: int64

# %%
# dataset['newcredit'] = dataset['Credit Score']

# %%
dataset.to_csv('Stage1.csv')

# %%
#######################################################################################

# %%
dataset = pd.read_csv("Stage1.csv")

# %%
dataset.head(1)
# Out:
#    Unnamed: 0 Loan Status  Current Loan Amount        Term  Credit Score  \
# 0           0  Fully Paid             445412.0  Short Term         709.0
#
#    Annual Income Years in current job Home Ownership            Purpose  \
# 0      1167493.0              8 years  Home Mortgage  Home Improvements
#
#    Monthly Debt  Years of Credit History  Months since last delinquent  \
# 0       5214.74                     17.2                           NaN
#
#    Number of Open Accounts  Number of Credit Problems  Current Credit Balance  \
# 0                      6.0                        1.0                228190.0
#
#    Maximum Open Credit  Bankruptcies  Tax Liens  debt_to_salary_ratio  \
# 0             416746.0           1.0        0.0            223.883262
#
#       binned
# 0  Excellent

# %% [markdown]
# Excellent/very good credit score: 700 to 850
# Good credit score: 680 to 699
# Average/OK credit score: 620 to 679
# Low credit score: 580 to 619
# Poor credit score: 500 to 579
# Bad credit score: 300 to 499

# %%
score = [300, 499, 579, 619, 679, 699, 850]
gags = [1,2,3,4,5,6]
tags = ['Bad','Poor','Low','Average','Good','Excellent']
dataset['binned'] = pd.cut(dataset['Credit Score'], bins=score, labels=tags)
# print (data_train)

# %%
#######################################################################################################

# %%
# dataset.head(1)

# %%
dataset.replace(np.inf, 0,inplace =True)

# %%
dataset['Income_Open_credit_ratio']= dataset['Maximum Open Credit']/dataset['Annual Income']

# %%
dataset['Income_Open_credit_ratio'].mean()
# Out:
# inf

# %%
dataset.columns.get_loc("Income_Open_credit_ratio")
# Out:
# 20

# %%
is_inf = dataset.loc[:, 'Income_Open_credit_ratio'] == np.inf
mean_ratio = dataset.ix[~is_inf, 'Income_Open_credit_ratio'].mean()
# Out:
# /home/ajaykrishna/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated

# %%
mean_ratio
# Out:
# 0.5846450731060379

# %%
plt.plot(dataset['Annual Income'],dataset['Maximum Open Credit'],'*')

# %%
dataset.sort_values(by=['Annual Income','Maximum Open Credit'],axis=0,ascending=True,inplace=True)

# %%
sam = dataset.head(100)

# %%
plt.plot(sam['Annual Income'],sam['Maximum Open Credit'],'*')

# %%
dataset.groupby('binned')['Credit Score','Current Loan Amount','debt_to_salary_ratio','Maximum Open Credit','Current Credit Balance','Years of Credit History','Income_Open_credit_ratio'].mean()
# Out:
#            Credit Score  Current Loan Amount  debt_to_salary_ratio  \
# binned
# Average      659.584837         1.184163e+07            119.457728
# Excellent    730.156273         1.900333e+07            123.079627
# Good         690.715373         1.211760e+07            117.730517
# Low          606.243292         1.044235e+07             89.573998
#
#            Maximum Open Credit  Current Credit Balance  \
# binned
# Average          592829.469466           315648.684421
# Excellent        794197.610068           290529.393777
# Good             614371.200621           301319.061646
# Low              635501.130590           349245.627907
#
#            Years of Credit History  Income_Open_credit_ratio
# binned
# Average                  17.504441                  0.453944
# Excellent                18.443586                  0.593301
# Good                     17.606351                  0.471322
# Low                      17.483721                  0.413654

# %%
dataset.groupby('binned')['Credit Score','Current Loan Amount','debt_to_salary_ratio','Maximum Open Credit','Current Credit Balance','Income_Open_credit_ratio'].median()
# Out:
#            Credit Score  Current Loan Amount  debt_to_salary_ratio  \
# binned
# Average           663.0             427581.0             65.217629
# Excellent         733.0             313588.0             73.170909
# Good              692.0             366476.0             66.297938
# Low               608.0             497684.0             64.516341
#
#            Maximum Open Credit  Current Credit Balance  \
# binned
# Average               438647.0                228114.0
# Excellent             484330.0                206739.0
# Good                  430661.0                216543.0
# Low                   447986.0                235163.0
#
#            Income_Open_credit_ratio
# binned
# Average                    0.363282
# Excellent                  0.420159
# Good                       0.373692
# Low                        0.313736

# %%
# dataset.groupby('binned')['Credit Score','Current Loan Amount','debt_to_salary_ratio','Maximum Open Credit','Current Credit Balance','Years of Credit History'].mode()

# %%
def credit_fillingNullvalues(data):
    i_open = data[0]
    creditScore = data[1]
    if pd.isnull(creditScore):
        if (i_open < 0.43):
            return 606
        if (i_open < 0.46):
            return 659
        if (i_open < 0.53):
            return 690
        else:
            return 730

# %%
# dataset['Credit Score'] = dataset[['Credit Score','Income_Open_credit_ratio']].apply(credit_fillingNullvalues,axis=1)
dataset['Credit Score']=dataset['Credit Score'].fillna(dataset[['Income_Open_credit_ratio','Credit Score']].apply(credit_fillingNullvalues,axis=1))

# %%
dataset.isnull().sum()
# Out:
# Unnamed: 0                          0
# Loan Status                         0
# Current Loan Amount                 0
# Term                                0
# Credit Score                        0
# Annual Income                       0
# Years in current job             3556
# Home Ownership                      0
# Purpose                             0
# Monthly Debt                        0
# Years of Credit History             0
# Months since last delinquent    45866
# Number of Open Accounts             0
# Number of Credit Problems           0
# Current Credit Balance              0
# Maximum Open Credit                 1
# Bankruptcies                      180
# Tax Liens                           9
# debt_to_salary_ratio            19154
# binned                          19154
# Income_Open_credit_ratio           18
# dtype: int64

# %%
dataset.head(1)
# Out:
#        Unnamed: 0 Loan Status  Current Loan Amount        Term  Credit Score  \
# 13470       14369  Fully Paid              79200.0  Short Term         730.0
#
#        Annual Income Years in current job Home Ownership             Purpose  \
# 13470            0.0            10+ years  Home Mortgage  Debt Consolidation
#
#        Monthly Debt           ...             Months since last delinquent  \
# 13470           0.0           ...                                      NaN
#
#        Number of Open Accounts  Number of Credit Problems  \
# 13470                      3.0                        0.0
#
#        Current Credit Balance  Maximum Open Credit  Bankruptcies  Tax Liens  \
# 13470                     0.0                  0.0           0.0        0.0
#
#        debt_to_salary_ratio  binned Income_Open_credit_ratio
# 13470                   NaN     NaN                      NaN
#
# [1 rows x 21 columns]

# %% [markdown]
# Months since last delinquent:
# As most of the customers haven't commited any crime irrespective of credit score or annual income etc, so for the missing values we have assumed to be zero. We try to build the model with and without this parameter, if there isn't any improvement we discard this feature
#
# Years in current job:
# This feature also doesn't have any kind of weightage to know the loan status, so we dropped this feature

# %%
dataset['Months since last delinquent'].fillna(0,inplace=True)
# dataset['Years in current job'].fillna(dataset['Years in current job'].mean(),inplace=True)
dataset.drop(["Years in current job"],axis =1,inplace =True)

# %%
dataset.isnull().sum()
# Out:
# Unnamed: 0                          0
# Loan Status                         0
# Current Loan Amount                 0
# Term                                0
# Credit Score                        0
# Annual Income                       0
# Home Ownership                      0
# Purpose                             0
# Monthly Debt                        0
# Years of Credit History             0
# Months since last delinquent        0
# Number of Open Accounts             0
# Number of Credit Problems           0
# Current Credit Balance              0
# Maximum Open Credit                 1
# Bankruptcies                      180
# Tax Liens                           9
# debt_to_salary_ratio            19154
# binned                          19154
# Income_Open_credit_ratio           18
# dtype: int64

# %%
# plt.plot(dataset['Credit Score'],data_train['Bankruptcies'],'*')

# %% [markdown]
# Bankruptcies and Tax Liens:
# For majority of the customers the bankruptcies and tax liens are zero so we assumed the missing values to be zero

# %%
dataset['Bankruptcies'].fillna(0,inplace=True)
dataset['Tax Liens'].fillna(0,inplace=True)

# %% [markdown]
# Maximum Open Credit:
# Previously we had computed "Income_Open_credit_ratio" through which we can get the Maximum Open Credit from Annual Income.

# %%
dataset['Maximum Open Credit'].fillna(dataset['Income_Open_credit_ratio']*dataset['Annual Income'],inplace=True)

# %%
dataset.dropna(axis=0,inplace=True)

# %%
dataset.isnull().sum()
# Out:
# Unnamed: 0                      0
# Loan Status                     0
# Current Loan Amount             0
# Term                            0
# Credit Score                    0
# Annual Income                   0
# Home Ownership                  0
# Purpose                         0
# Monthly Debt                    0
# Years of Credit History         0
# Months since last delinquent    0
# Number of Open Accounts         0
# Number of Credit Problems       0
# Current Credit Balance          0
# Maximum Open Credit             0
# Bankruptcies                    0
# Tax Liens                       0
# debt_to_salary_ratio            0
# binned                          0
# Income_Open_credit_ratio        0
# dtype: int64

# %%
dataset.drop(['debt_to_salary_ratio','binned','Income_Open_credit_ratio','Unnamed: 0'],axis=1,inplace = True)

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 66080 entries, 58618 to 34730
# Data columns (total 16 columns):
# Loan Status                     66080 non-null object
# Current Loan Amount             66080 non-null float64
# Term                            66080 non-null object
# Credit Score                    66080 non-null float64
# Annual Income                   66080 non-null float64
# Home Ownership                  66080 non-null object
# Purpose                         66080 non-null object
# Monthly Debt                    66080 non-null float64
# Years of Credit History         66080 non-null float64
# Months since last delinquent    66080 non-null float64
# Number of Open Accounts         66080 non-null float64
# Number of Credit Problems       66080 non-null float64
# Current Credit Balance          66080 non-null float64
# Maximum Open Credit             66080 non-null float64
# Bankruptcies                    66080 non-null float64
# Tax Liens                       66080 non-null float64
# dtypes: float64(12), object(4)
# memory usage: 8.6+ MB

# %% [markdown]
# # Coverting the categorical data to numeric data

# %%
categorical_data = dataset.select_dtypes(include=['object'])
categorical_data.head()
# Out:
#        Loan Status        Term Home Ownership               Purpose
# 58618  Charged Off  Short Term           Rent    Debt Consolidation
# 45802   Fully Paid  Short Term           Rent  Educational Expenses
# 59073   Fully Paid  Short Term       Own Home    Debt Consolidation
# 12279   Fully Paid  Short Term           Rent    Debt Consolidation
# 84892   Fully Paid  Short Term           Rent                 Other

# %%
dataset.groupby('Loan Status').mean()
# Out:
#              Current Loan Amount  Credit Score  Annual Income  Monthly Debt  \
# Loan Status
# Charged Off         3.241032e+05    710.207678   1.254555e+06  18727.686879
# Fully Paid          2.173728e+07    721.217630   1.410721e+06  18334.178680
#
#              Years of Credit History  Months since last delinquent  \
# Loan Status
# Charged Off                17.907923                     15.797851
# Fully Paid                 18.358215                     16.357537
#
#              Number of Open Accounts  Number of Credit Problems  \
# Loan Status
# Charged Off                11.237144                   0.170551
# Fully Paid                 11.102001                   0.165010
#
#              Current Credit Balance  Maximum Open Credit  Bankruptcies  \
# Loan Status
# Charged Off           285282.317877        630784.825500      0.112568
# Fully Paid            296398.212426        787854.843526      0.117257
#
#              Tax Liens
# Loan Status
# Charged Off   0.033573
# Fully Paid    0.027648

# %%
# # dataset["Loan_status"] = dataset["Loan Status"].cat.codes
# from sklearn.preprocessing import LabelEncoder

# lb_make = LabelEncoder()
# obj_df["make_code"] = lb_make.fit_transform(obj_df["make"])

# %%
dataset.groupby('Term').mean()
# Out:
#             Current Loan Amount  Credit Score  Annual Income  Monthly Debt  \
# Term
# Long Term          1.372104e+07    697.005874   1.524161e+06   21577.65962
# Short Term         1.903026e+07    726.986534   1.329708e+06   17280.34867
#
#             Years of Credit History  Months since last delinquent  \
# Term
# Long Term                 18.693452                     16.005644
# Short Term                18.121716                     16.337528
#
#             Number of Open Accounts  Number of Credit Problems  \
# Term
# Long Term                 11.798664                   0.145819
# Short Term                10.888804                   0.173290
#
#             Current Credit Balance  Maximum Open Credit  Bankruptcies  \
# Term
# Long Term            357625.194483        890174.996199      0.100207
# Short Term           271686.384165        710569.424173      0.122116
#
#             Tax Liens
# Term
# Long Term    0.027298
# Short Term   0.029313

# %%
dataset.groupby('Home Ownership').mean()
# Out:
#                 Current Loan Amount  Credit Score  Annual Income  \
# Home Ownership
# HaveMortgage           1.982990e+07    718.857143   1.402449e+06
# Home Mortgage          1.803786e+07    720.592328   1.573903e+06
# Own Home               1.729980e+07    717.908956   1.248044e+06
# Rent                   1.722767e+07    717.643446   1.184758e+06
#
#                 Monthly Debt  Years of Credit History  \
# Home Ownership
# HaveMortgage    18119.963946                18.711565
# Home Mortgage   21014.097872                19.576277
# Own Home        16939.342042                18.941366
# Rent            15698.091013                16.602709
#
#                 Months since last delinquent  Number of Open Accounts  \
# Home Ownership
# HaveMortgage                       15.836735                10.176871
# Home Mortgage                      16.774129                11.820682
# Own Home                           16.028699                10.977899
# Rent                               15.690647                10.358435
#
#                 Number of Credit Problems  Current Credit Balance  \
# Home Ownership
# HaveMortgage                     0.204082           252038.619048
# Home Mortgage                    0.165198           356022.222891
# Own Home                         0.180934           294742.017318
# Rent                             0.163628           222419.674986
#
#                 Maximum Open Credit  Bankruptcies  Tax Liens
# Home Ownership
# HaveMortgage           3.151969e+06      0.142857   0.040816
# Home Mortgage          9.634925e+05      0.113897   0.029638
# Own Home               7.716115e+05      0.122876   0.033482
# Rent                   5.022360e+05      0.117658   0.026693

# %%
dataset["Home Ownership"].replace("HaveMortgage","Home Mortgage",inplace=True)

# %%
dataset.groupby('Purpose').mean()
# Out:
#                       Current Loan Amount  Credit Score  Annual Income  \
# Purpose
# Business Loan                1.234118e+07    703.461224   1.581012e+06
# Buy House                    1.700852e+07    706.901376   1.490341e+06
# Buy a Car                    2.034838e+07    726.621005   1.210631e+06
# Debt Consolidation           1.768663e+07    720.221283   1.364015e+06
# Educational Expenses         1.983862e+07    725.070423   1.073406e+06
# Home Improvements            1.859261e+07    720.360862   1.676564e+06
# Medical Bills                1.835750e+07    711.515278   1.423045e+06
# Other                        1.868679e+07    719.398708   1.357728e+06
# Take a Trip                  1.727888e+07    715.166213   1.245833e+06
# major_purchase               1.878488e+07    723.541322   1.464043e+06
# moving                       1.995818e+07    701.435644   1.597210e+06
# other                        1.603456e+07    709.411364   1.291573e+06
# renewable_energy             2.090704e+05    710.600000   1.473043e+06
# small_business               1.432979e+07    701.951351   1.542083e+06
# vacation                     1.262010e+07    712.946429   1.206528e+06
# wedding                      2.617593e+07    718.194805   1.454830e+06
#
#                       Monthly Debt  Years of Credit History  \
# Purpose
# Business Loan         16099.528051                18.197857
# Buy House             14702.934289                17.127064
# Buy a Car             13134.285947                17.700913
# Debt Consolidation    19039.761116                18.308412
# Educational Expenses  11449.929859                20.301408
# Home Improvements     17844.706486                19.093434
# Medical Bills         17966.584986                19.256667
# Other                 14525.616525                17.223950
# Take a Trip           15513.702943                17.410899
# major_purchase        14235.397479                18.011570
# moving                18259.570000                16.749505
# other                 15915.828838                17.808106
# renewable_energy      18331.542000                27.300000
# small_business        15401.077514                17.989730
# vacation              17727.498750                16.921429
# wedding               15295.903117                16.267532
#
#                       Months since last delinquent  Number of Open Accounts  \
# Purpose
# Business Loan                            16.541837                 9.643878
# Buy House                                16.222477                 9.974771
# Buy a Car                                14.549087                 9.509132
# Debt Consolidation                       16.189129                11.423197
# Educational Expenses                     13.915493                10.126761
# Home Improvements                        18.077456                10.744550
# Medical Bills                            15.120833                10.534722
# Other                                    14.576373                 9.636825
# Take a Trip                              16.294278                 9.692098
# major_purchase                           15.644628                 9.404959
# moving                                   16.396040                10.990099
# other                                    16.671465                 9.764141
# renewable_energy                         28.400000                12.200000
# small_business                           15.945946                 9.778378
# vacation                                 23.607143                10.589286
# wedding                                  15.064935                 9.753247
#
#                       Number of Credit Problems  Current Credit Balance  \
# Purpose
# Business Loan                          0.152041           272572.778571
# Buy House                              0.181193           207161.575688
# Buy a Car                              0.143836           208287.087900
# Debt Consolidation                     0.163464           309791.959663
# Educational Expenses                   0.028169           208156.507042
# Home Improvements                      0.217492           272959.735573
# Medical Bills                          0.208333           244046.054167
# Other                                  0.125981           204170.405168
# Take a Trip                            0.198910           192223.000000
# major_purchase                         0.161157           166477.528926
# moving                                 0.138614           201717.920792
# other                                  0.169949           229489.374495
# renewable_energy                       0.000000           347301.000000
# small_business                         0.205405           272726.821622
# vacation                               0.285714           211334.285714
# wedding                                0.051948           184281.000000
#
#                       Maximum Open Credit  Bankruptcies  Tax Liens
# Purpose
# Business Loan                1.077472e+06      0.088776   0.037755
# Buy House                    7.231396e+05      0.128440   0.036697
# Buy a Car                    9.587017e+05      0.099315   0.019406
# Debt Consolidation           7.299802e+05      0.116466   0.027494
# Educational Expenses         6.060668e+05      0.000000   0.000000
# Home Improvements            1.033956e+06      0.155168   0.030777
# Medical Bills                6.075219e+05      0.130556   0.048611
# Other                        8.018361e+05      0.074758   0.031380
# Take a Trip                  1.485534e+06      0.149864   0.027248
# major_purchase               5.704775e+05      0.107438   0.049587
# moving                       5.485508e+05      0.059406   0.069307
# other                        7.005264e+05      0.109091   0.035101
# renewable_energy             7.924664e+05      0.000000   0.000000
# small_business               6.071955e+05      0.124324   0.048649
# vacation                     5.364845e+05      0.089286   0.071429
# wedding                      5.176620e+05      0.025974   0.000000

# %%
dataset["Purpose"].replace("other","Other",inplace=True)

# %%
char_cols=categorical_data.columns

# %%
label_mapping = {}

for c in char_cols:
    dataset[c], label_mapping[c] = pd.factorize(dataset[c])

# %%
dataset.head(20)
# Out:
#        Loan Status  Current Loan Amount  Term  Credit Score  Annual Income  \
# 58618            0              30448.0     0         736.0        76627.0
# 45802            1              61490.0     0         662.0        81092.0
# 59073            1           99999999.0     0         737.0        94867.0
# 12279            1              22462.0     0         738.0        97033.0
# 84892            1           99999999.0     0         745.0       106533.0
# 9051             1              34342.0     0         715.0       111245.0
# 22378            1              47894.0     0         688.0       130150.0
# 26903            1              46860.0     0         714.0       134881.0
# 11754            1           99999999.0     0         718.0       135071.0
# 12654            1              22352.0     0         718.0       135071.0
# 9620             1              26730.0     0         725.0       144267.0
# 78553            1           99999999.0     0         725.0       144267.0
# 44377            0              70224.0     0         746.0       149264.0
# 20956            1           99999999.0     0         734.0       149891.0
# 26218            1              65098.0     0         745.0       149986.0
# 22959            1              46530.0     0         704.0       151278.0
# 27105            0              49896.0     1         728.0       153178.0
# 46571            0              51106.0     0         738.0       156104.0
# 50591            0              53680.0     0         718.0       158403.0
# 6316             1           99999999.0     0         727.0       160075.0
#
#        Home Ownership  Purpose  Monthly Debt  Years of Credit History  \
# 58618               0        0        845.50                      9.5
# 45802               0        1          0.00                     11.0
# 59073               1        0       2656.01                      8.5
# 12279               0        0       1455.59                     12.0
# 84892               0        2        329.27                     11.8
# 9051                1        2        463.60                     29.7
# 22378               1        2       2971.41                     21.3
# 26903               0        0       1641.22                      6.0
# 11754               0        3       1519.43                     29.0
# 12654               0        3       1519.43                     29.0
# 9620                0        2       2572.79                      9.5
# 78553               0        2       2572.79                      9.5
# 44377               0        0       1716.46                     19.2
# 20956               0        1        960.64                     14.0
# 26218               0        3       1087.37                     11.7
# 22959               1        2       3504.74                     11.5
# 27105               0        0       1914.82                      9.9
# 46571               1        2        372.02                      9.3
# 50591               1        0       3484.79                     26.9
# 6316                0        0       2774.76                     13.3
#
#        Months since last delinquent  Number of Open Accounts  \
# 58618                           0.0                      8.0
# 45802                           0.0                      6.0
# 59073                           0.0                     11.0
# 12279                           0.0                      5.0
# 84892                           0.0                      4.0
# 9051                           23.0                      3.0
# 22378                           0.0                      3.0
# 26903                           0.0                      4.0
# 11754                           0.0                      3.0
# 12654                           0.0                      3.0
# 9620                            0.0                      4.0
# 78553                           0.0                      4.0
# 44377                           0.0                      6.0
# 20956                           0.0                      6.0
# 26218                           0.0                     12.0
# 22959                          41.0                      4.0
# 27105                           0.0                      5.0
# 46571                           0.0                      2.0
# 50591                           0.0                      5.0
# 6316                            0.0                      3.0
#
#        Number of Credit Problems  Current Credit Balance  Maximum Open Credit  \
# 58618                        0.0                 28177.0             147598.0
# 45802                        0.0                     0.0                  0.0
# 59073                        0.0                 86925.0             190982.0
# 12279                        0.0                 18658.0              83050.0
# 84892                        0.0                 10963.0             147598.0
# 9051                         0.0                  6840.0             264044.0
# 22378                        0.0                100510.0             191730.0
# 26903                        0.0                 43491.0              89298.0
# 11754                        0.0                 43453.0              58080.0
# 12654                        0.0                 43453.0              58080.0
# 9620                         0.0                119928.0             267058.0
# 78553                        0.0                119928.0             267058.0
# 44377                        0.0                 95836.0             317922.0
# 20956                        0.0                 21375.0              26708.0
# 26218                        0.0                 49362.0             158312.0
# 22959                        0.0                100643.0             251702.0
# 27105                        0.0                 53789.0             853138.0
# 46571                        0.0                  9044.0              32230.0
# 50591                        0.0                102486.0             132000.0
# 6316                         0.0                 70357.0              99594.0
#
#        Bankruptcies  Tax Liens
# 58618           0.0        0.0
# 45802           0.0        0.0
# 59073           0.0        0.0
# 12279           0.0        0.0
# 84892           0.0        0.0
# 9051            0.0        0.0
# 22378           0.0        0.0
# 26903           0.0        0.0
# 11754           0.0        0.0
# 12654           0.0        0.0
# 9620            0.0        0.0
# 78553           0.0        0.0
# 44377           0.0        0.0
# 20956           0.0        0.0
# 26218           0.0        0.0
# 22959           0.0        0.0
# 27105           0.0        0.0
# 46571           0.0        0.0
# 50591           0.0        0.0
# 6316            0.0        0.0

# %%
label_mapping
# Out:
# {'Loan Status': Index(['Charged Off', 'Fully Paid'], dtype='object'),
#  'Term': Index(['Short Term', 'Long Term'], dtype='object'),
#  'Home Ownership': Index(['Rent', 'Own Home', 'Home Mortgage'], dtype='object'),
#  'Purpose': Index(['Debt Consolidation', 'Educational Expenses', 'Other', 'Buy a Car',
#         'Home Improvements', 'Business Loan', 'Medical Bills', 'Take a Trip',
#         'moving', 'Buy House', 'major_purchase', 'small_business', 'vacation',
#         'wedding', 'renewable_energy'],
#        dtype='object')}

# %%
dataset.to_csv('processed_data.csv')
